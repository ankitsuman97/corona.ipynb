# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r"C:\Users\Swapnil\Downloads\corona1.xlsx")
df
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                    China       80651      99.0       3070.0       28.0
# 1                 S. Korea        6767     174.0         44.0        1.0
# 2                     Iran        4747       NaN        124.0        NaN
# 3                    Italy        4636       NaN        197.0        NaN
# 4         Diamond Princess         696       NaN          6.0        NaN
# 5                  Germany         670       NaN          NaN        NaN
# 6                   France         653       NaN          9.0        NaN
# 7                    Japan         420       NaN          6.0        NaN
# 8                    Spain         402       1.0          8.0        NaN
# 9                      USA         335      16.0         17.0        2.0
# 10             Switzerland         214       NaN          1.0        NaN
# 11                      UK         164       NaN          2.0        NaN
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                    China       80651      99.0       3070.0       28.0
# 1                 S. Korea        6767     174.0         44.0        1.0
# 2                     Iran        4747       NaN        124.0        NaN
# 3                    Italy        4636       NaN        197.0        NaN
# 4         Diamond Princess         696       NaN          6.0        NaN
# 5                  Germany         670       NaN          NaN        NaN
# 6                   France         653       NaN          9.0        NaN
# 7                    Japan         420       NaN          6.0        NaN
# 8                    Spain         402       1.0          8.0        NaN
# 9                      USA         335      16.0         17.0        2.0
# 10             Switzerland         214       NaN          1.0        NaN
# ...

# %%
df.index
df.columns
# Out:
# Index(['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
#        'ActiveCases', 'TotalRecovered', 'Serious,Critical'],
#       dtype='object')
